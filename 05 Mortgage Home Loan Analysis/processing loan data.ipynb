# %%
import pandas as pd
import os
from sql_table_schema_parser import SQLTableSchemaParser 
from sql_commands import create_table

# %%
# Instantiate parser
sql_parser = SQLTableSchemaParser(sql_command=create_table)

# Get schema and date columns
schema_dict = sql_parser.get_schema_dict()
date_col_indices = sql_parser.get_date_col_indices()

columns = schema_dict.keys()

bool_col_indices = sql_parser.get_bool_col_indices()

# %%
df = pd.read_csv('sf-loan-performance-data-sample.csv', sep="|", header=None, names=columns)
df.head()
# Out:
#    Reference_Pool_ID  Loan_Identifier  Monthly_Reporting_Period Channel  \
# 0                NaN     100023020488                     82009       R
# 1                NaN     100023020488                     92009       R
# 2                NaN     100023020488                    102009       R
# 3                NaN     100023020488                    112009       R
# 4                NaN     100023020488                    122009       R
#
#   Seller_Name Servicer_Name  Master_Servicer  Original_Interest_Rate  \
# 0       Other         Other              NaN                   5.375
# 1       Other         Other              NaN                   5.375
# 2       Other         Other              NaN                   5.375
# 3       Other         Other              NaN                   5.375
# 4       Other         Other              NaN                   5.375
#
#    Current_Interest_Rate  Original_UPB  ...  ARM_Plan_Number  \
# 0                  5.375       55000.0  ...              NaN
# 1                  5.375       55000.0  ...              NaN
# 2                  5.375       55000.0  ...              NaN
# 3                  5.375       55000.0  ...              NaN
# 4                  5.375       55000.0  ...              NaN
#
#    Borrower_Assistance_Plan  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#    High_Loan_to_Value_HLTV_Refinance_Option_Indicator  Deal_Name  \
# 0                                                  N         NaN
# 1                                                  N         NaN
# 2                                                  N         NaN
# 3                                                  N         NaN
# 4                                                  N         NaN
#
#    Repurchase_Make_Whole_Proceeds_Flag  Alternative_Delinquency_Resolution  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#    Alternative_Delinquency_Resolution_Count  Total_Deferral_Amount  \
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
#
#    Payment_Deferral_Modification_Event_Indicator  Interest_Bearing_UPB
# 0                                            NaN                   NaN
# 1                                            NaN                   NaN
# 2                                            NaN                   NaN
# 3                                            NaN                   NaN
# 4                                            NaN                   NaN
#
# [5 rows x 110 columns]

# %%
date_df = df.iloc[:,date_col_indices]
date_df
# Out:
#      Monthly_Reporting_Period  Origination_Date  First_Payment_Date  \
# 0                       82009             82009              102009
# 1                       92009             82009              102009
# 2                      102009             82009              102009
# 3                      112009             82009              102009
# 4                      122009             82009              102009
# ..                        ...               ...                 ...
# 752                     22020             72009               92009
# 753                     32020             72009               92009
# 754                     42020             72009               92009
# 755                     52020             72009               92009
# 756                     62020             72009               92009
#
#      Maturity_Date  Interest_Only_First_Principal_And_Interest_Payment_Date  \
# 0          92029.0                                                NaN
# 1          92029.0                                                NaN
# 2          92029.0                                                NaN
# 3          92029.0                                                NaN
# 4          92029.0                                                NaN
# ..             ...                                                ...
# 752        82039.0                                                NaN
# 753        82039.0                                                NaN
# 754        82039.0                                                NaN
# 755        82039.0                                                NaN
# 756        82039.0                                                NaN
#
#      Zero_Balance_Effective_Date  Repurchase_Date  Last_Paid_Installment_Date  \
# 0                            NaN              NaN                         NaN
# 1                            NaN              NaN                         NaN
# 2                            NaN              NaN                         NaN
# 3                            NaN              NaN                         NaN
# 4                            NaN              NaN                         NaN
# ..                           ...              ...                         ...
# 752                          NaN              NaN                         NaN
# 753                          NaN              NaN                         NaN
# 754                          NaN              NaN                         NaN
# 755                          NaN              NaN                         NaN
# 756                          NaN              NaN                         NaN
#
#      Foreclosure_Date  Disposition_Date  Original_List_Start_Date  \
# 0                 NaN               NaN                       NaN
# 1                 NaN               NaN                       NaN
# 2                 NaN               NaN                       NaN
# 3                 NaN               NaN                       NaN
# 4                 NaN               NaN                       NaN
# ..                ...               ...                       ...
# 752               NaN               NaN                       NaN
# 753               NaN               NaN                       NaN
# 754               NaN               NaN                       NaN
# 755               NaN               NaN                       NaN
# 756               NaN               NaN                       NaN
#
#      Current_List_Start_Date  Zero_Balance_Code_Change_Date  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
# ..                       ...                            ...
# 752                      NaN                            NaN
# 753                      NaN                            NaN
# 754                      NaN                            NaN
# 755                      NaN                            NaN
# 756                      NaN                            NaN
#
#      Loan_Holdback_Effective_Date  Next_Interest_Rate_Adjustment_Date  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
# ..                            ...                                 ...
# 752                           NaN                                 NaN
# 753                           NaN                                 NaN
# 754                           NaN                                 NaN
# 755                           NaN                                 NaN
# 756                           NaN                                 NaN
#
#      Next_Payment_Change_Date
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 752                       NaN
# 753                       NaN
# 754                       NaN
# 755                       NaN
# 756                       NaN
#
# [757 rows x 16 columns]

# %%
bool_df = df.iloc[:,bool_col_indices]
# file_path = 'og_bool_check.csv'
# bool_df.to_csv(file_path, index=False)
